# %%
import timeit
code="""
from random import randint
array = [randint(1, 100) for _ in range(1000)]
sort_result = merge_sort(array)
result = search_matched_sum(sort_result, 10)
print(result)
"""
setup="""
def search_matched_sum(arr : list, target : int):
    min_index = ()
    for i in range(0,len(arr)):
        for j in range(i+1,len(arr)):
            sum = arr[i] + arr[j]
            if sum == target:
                min_index = (i,j)
                break
        
    return min_index     

def merge_sort(arr : list):
    if len(arr) > 1:
        mid = len(arr) // 2 
        left = arr[:mid]  
        right = arr[mid:]  

        merge_sort(left)
        merge_sort(right)

        i = j = k = 0
        
        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
            k += 1

        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1
            
    return arr
"""
#call the timeit() method 4 times
print(timeit.timeit(stmt = code, setup = setup, number = 500))

# %%
import timeit
code="""
from random import randint
array = [randint(1, 100) for _ in range(1000)]
sort_result = merge_sort(array)
result = search_matched_sum(sort_result, 40)

print(result)
"""
setup="""
def search_matched_sum(arr : list, target : int):
    low = 0
    high = len(arr)-1
    min_index = []
    while (low <= high) :
        sum = arr[low]+ arr[high]
        if sum == target:
            min_index = (low,high)
        if target < sum:
            high -= 1
        else: 
            low += 1
    
    return min_index 

def merge_sort(unsorted_array):
    if len(unsorted_array) > 1:
        mid = len(unsorted_array) // 2 
        left = unsorted_array[:mid]
        right = unsorted_array[mid:] 

        merge_sort(left)
        merge_sort(right)

        i = j = k = 0
        
        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                unsorted_array[k] = left[i]
                i += 1
            else:
                unsorted_array[k] = right[j]
                j += 1
            k += 1

        while i < len(left):
            unsorted_array[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            unsorted_array[k] = right[j]
            j += 1
            k += 1
    return unsorted_array
"""

#call the timeit() method 4 times
print(timeit.timeit(stmt = code, setup = setup, number = 1000))
# Out:
# (1926, 1934)
# (1893, 1908)
# (1926, 1993)
# (1943, 1971)
# (1981, 1982)
# (1866, 1922)
# (1922, 1998)
# (1982, 1985)
# (1981, 1988)
# (1962, 1965)
# (1884, 1952)
# (1964, 1997)
# (1947, 1980)
# (1944, 1989)
# (1959, 1992)
# (1971, 1985)
# (1972, 1988)
# (1973, 1978)
# (1987, 1995)
# (1896, 1996)
# (1991, 1992)
# (1934, 1978)
# (1978, 1991)
# (1911, 1938)
# (1960, 1995)
# (1934, 1938)
# (1860, 1983)
# (1959, 1969)
# (1895, 1901)
# (1974, 1990)
# (1967, 1986)
# (1982, 1997)
# (1984, 1997)
# (1960, 1969)
# (1865, 1966)
# (1964, 1999)
# (1929, 1992)
# (1963, 1988)
# (1969, 1992)
# (1931, 1989)
# (1937, 1990)
# (1927, 1936)
# (1917, 1983)
# (1927, 1982)
# (1983, 1997)
# (1945, 1969)
# (1960, 1993)
# (1926, 1989)
# (1948, 1987)
# (1940, 1991)
# (1912, 1984)
# (1981, 1993)
# (1919, 1949)
# (1914, 1976)
# (1940, 1965)
# (1981, 1999)
# (1903, 1946)
# (1965, 1989)
# (1971, 1976)
# (1948, 1949)
# (1982, 1984)
# (1942, 1996)
# (1986, 1987)
# (1972, 1982)
# (1955, 1985)
# (1867, 1943)
# ...

# %% [markdown]
# n = 10
# 0.014632799997343682
# 0.016207100001338404
# 0.014584699994884431
# 0.011030400004528929
# 0.015912000002572313

# %% [markdown]
# n = 100
# 0.19423890000325628
# 0.18732099999760976
# 0.1936820999981137
# 0.20948949999728939
# 0.22016270000312943

# %% [markdown]
# n = 500
# 3.3182555999992474
# 3.2596438999989914
# 3.3978530000003957
# 3.3448659000005136
# 4.412095699999554

# %% [markdown]
# -----------------------

# %% [markdown]
# n = 1000
# target = 10
#
# sorting
# 8.327659500002483
# 8.19700880000164
# 8.287642800001777
# 8.128044400000363
# 8.374298299997463
#
# non sotring
# 8.396090899994306
# 8.557726400002139
# 8.664758299993991
# 8.60920819999592
# 8.71772339999734

# %%
n = 2000
target = 10

sorting
31.65795369999978

non sorting
34.39248049999878

# %% [markdown]
# -----------------------

# %% [markdown]
# n = 1000
#
# sorting
#
# non break
# 12.653611399997317
# 12.10868869999831
# 12.307116799995129
# 11.71589519999543
# 12.437294800001837
#
# break
# 9.624507200001972
# 9.249884400000155
# 9.377225200005341
# 9.13294479999604
# 9.297368100000313
#
# non sorting
#
# non break
# 8.462720299998182
# 8.357469599999604
# 8.30484929999875
# 8.356986300001154
# 8.327659500002483
#
# break
# 4.8109187000009115
# 4.709702100000868
# 4.789424499998859
# 4.662058899997646
# 4.756575799998245

# %% [markdown]
# n = 10000 1128.682828500001

# %% [markdown]
# 생각할것
# 1.왜 마지막 인덱스만 적는지
# 2.정렬
# 3.break 사용한다면?

# %% [markdown]
# 두 숫자의 합이 target과 일치하는 예제에서 실생활에 적용될 선형관계를 나타내보고 싶다.
# 인스타그램 친구를 찾기 위해선 먼저 정렬을 하고 입력한 arr(list)와 동일한 target을 보여 줄 것이다.
# a+b = target / 성 + 이름 = 찾는 사람 이름
# 인덱스를 나열 해 줄 때, 내가 적은 코드에선 처음 찾는 arr를 무시하고 마지막에 나타난 arr을 return 해주는 방식으로 코드를 작성했다.
# 그 이유는 수 많은 경우가 있을테지만, 정렬 후 동일한 이름을 가진 사람들이 나올텐데, 그 상황에 맞춰 보고서를 적어보고자 이렇게 설정했다.
#
# 구글 사람 이름 검색 수많은 게시물중 랜덤으로 띄어줄 것인데,
#
# # 잭팟 마지막 777 잭팟 예시 비록 과제는 a+b 두개 지만 빗대어 설명하면 결국 마지막 한번 터지는 결과를 알고 싶기에 설정했다.

# %% [markdown]
# 무작위 숫자를 뽑고 무작위로 추출한 두 수의 합이 같을때,
