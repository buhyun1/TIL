# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\hwang\miniconda3\envs\esports\lib\site-packages (4.66.1)
# Requirement already satisfied: colorama in c:\users\hwang\miniconda3\envs\esports\lib\site-packages (from tqdm) (0.4.4)

# %%
import requests
import json
import time
import pandas as pd
from tqdm import tqdm

api_key = 'RGAPI-b3f2aaea-f645-44f7-b0d0-0fa3e0b79e29'

# %%
#챌린저 등급 솔로 랭크 게임을 플레이한 플레이어의 summoner id 추출
url = 'https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key=' + api_key

summonerId = {}

r = requests.get(url)
r = r.json()['entries']

num = 0

for i in r:
    summonerId[i['summonerName']] = i['summonerId']
    num += 1
print(num)
# Out:
# 300

# %%
from numpy.lib.function_base import kaiser
# summonerId를 통해 puuid 추출
print(summonerId)

allcnt = 0
bluewincnt = 0

for i,j in zip(tqdm(summonerId.values()),summonerId.keys()):
  try:
    # summoner id를 가지고 puuid 조회
    url2 = 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/' + i + '?api_key=' + api_key
    r = requests.get(url2)
    r.json()

    # puuid를 가지고 matchid 조회
    url_match = 'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/'+ r.json()['puuid'] +'/ids?start=1&count=5&api_key='+api_key
    r_match = requests.get(url_match)

    # matchid를 가지고 게임 내부기록 조회
    url_match = 'https://asia.api.riotgames.com/lol/match/v5/matches/' + r_match.json()[0] + '?api_key=' + api_key
    r_match = requests.get(url_match)

    # 블루진영 레드진영 이긴횟수 카운팅
    for k in range(len(r_match.json()['info']['participants'])):
      if r_match.json()['info']['participants'][k]['summonerName'] == j:
          if r_match.json()['info']['participants'][k]['teamId'] == 100:
              bluewincnt+=1
              allcnt+=1
          else:
              allcnt+=1
  except:
    continue

print()
print('블루팀이 이긴횟수: ', bluewincnt/allcnt)
# Out:
# {'Strong7': 'FOcixe0FPeRpC4GLvgQ-6djFK5yYkAvRpiqT9wLB6OySd13o0puhfjOrkA', 'Faker 십년 팬': 'mf1UNq73os_IRlDizAy6xIaJ85cD5hmx0xUPBJhlHpgnozOXZ6BnrUe03g', '푸른 갈대': '7PNVBTVUz2TbGAoVgnUYCVYoLYiBeoW5OfJ_ZutUz8t3DJQ4tmQugtvqJg', 'TF Blade2': 'tDjCLwMxOfGllzHj8jDNrEaShW0VO0Ix4C2cF0QB4d8to3GCGpHLShf4lw', 'viper3': 'vi0uCr86kbe6UPY1BBVz2Rk8u6Mfvtiitrs-gGpN0_SAAOM', 'Kiw1 doctor': 'Kna0hgKzpKcCWtMVJaqAros5bvIMMHSb7EmGzgGu1UlUSz_1gwfeVL5iYA', '전설이 될 남자': 'EZe9gTQaQYeUGGBXxmjkS1CsyMH8JSpHXXQV26XuDJ87hLlpGCh4Ks4dUg', '펭로스': 'z2kzEIdrrxMVUNFZykWGs9JxPcai2WlnMyMoyPoWqtZrXkk', 'WAX PRODUCT': 'Uxt4PrlT1heu5M9-M8wKkf4BnhikbIRSHkUWgE9C6pN5LmvFGsIyOmbCUw', '수명단축협곡': 'h0b8yAEab7zXTAK1VIX_u4DxdrIuAie2vpFqX2mE8Zb1D30', 'Chu성훈': '-MX1WlpSyH8xRAXzSYQipYMJ71IBcVtQc_BSv0vH9I2SwuY', 'Fisherr': 'k-D0v2WhN7sdxlkDAR
 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/' + 'tUKg7AOQXLN04DjqNWILCjATOkA7S1lmMVEpFNoMgjmttpRFEd_XA9lYHg' + '?api_key=' + api_key
r = requests.get(url2)
r.json() # json 결과
# Out:
# {'id': 'tUKg7AOQXLN04DjqNWILCjATOkA7S1lmMVEpFNoMgjmttpRFEd_XA9lYHg',
#  'accountId': 'uAmXO1K8uzZiEASWPxVFhYMFEklyrSVHuRnuteecquebmPkiQKwBwo7O',
#  'puuid': 'nAbtuqPG74lMCmjoMAQdtYLPqdHumpQ4y1Pg1xpODNUykl6Vz7RQA8FprQu8CJWu-bOOezPDKq985g',
#  'name': 'Strong7',
#  'profileIconId': 5914,
#  'revisionDate': 1691472572000,
#  'summonerLevel': 178}

# %%
url_match = 'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/'+ 'nAbtuqPG74lMCmjoMAQdtYLPqdHumpQ4y1Pg1xpODNUykl6Vz7RQA8FprQu8CJWu-bOOezPDKq985g' +'/ids?start=1&count=5&api_key='+api_key
r_match = requests.get(url_match)
r_match.json()
# Out:
# ['KR_6639461146',
#  'KR_6639454082',
#  'KR_6639441469',
#  'KR_6639435062',
#  'KR_6639423487']

# %%
url_match = 'https://asia.api.riotgames.com/lol/match/v5/matches/' + 'KR_6639461146' + '?api_key=' + api_key
r_match = requests.get(url_match)
r_match.json()
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_6639461146',
#   'participants': ['MbZ95JD7BR6Nr-bh8Vy1wosMwQMlpWi89FAT7y6h2czW25ilP-7xbL0mbk0M6wsITNgqCKr7STCsjQ',
#    'H319LfhyxTWa3PFBbE3HnSnIhiHlXY4jN0zbVMCkT6rRfWahodKdIhJFHYzY1cxFqj_TBxgxvhAnOQ',
#    'JTwZ5Nv3wM4IVwZgXSDtySg4QndH-zhD5dheb9YUpvDGRLXzDoy4Z7bM61T8ULhCvcPaa3F6ovCgAw',
#    'a63bL3nfpkeA1fAqnpFDva147DIMBqNDEdw-fDU_WnfjmlGGkJbzBwWGshn59KzBG0nmAPmH9xk-ug',
#    'nAbtuqPG74lMCmjoMAQdtYLPqdHumpQ4y1Pg1xpODNUykl6Vz7RQA8FprQu8CJWu-bOOezPDKq985g',
#    '7JAOhJxgYmBD_ZYO8G7gh0b5RHPDC-w0zcPfU6bkCJtqacxxexbBWgmw1KT9g5ulbgMLT3sbxGg_Jw',
#    'csMd3OMtxw_y7lOFa-A1DYKJMWT9tCLR5INz_Ji5XyDdxFTU2gbqi36ObDw6VieApvTMowsZ-NssWg',
#    'wvLo-emSen_5rhHXF4JPEcCjtkVK5iRJ3e1uDcnTpiFZiu4ekiuui6YFoMym7T9U-P6Q-ItEQ3t-zg',
#    '4yhdUvNU66fCtD1IepEEbtTxDytsnAkohzOoHBkQEvMr9hHjW-RqGlPxo7wB5t9eh7JSUsuGhopBWg',
#    'rr8vp_is13emhYvFgjBVT4lryS0ykrArxIolVrwJi9LID6zoa9uYDb271aRfP7EFtb-CJWH2SdL7IA']},
#  'info': {'gameCreation': 1691448906658,
#   'gameDuration': 972,
#   'gameEndTimestamp': 1691449893922,
#   'gameId': 6639461146,
#   'gameMode': 'ARAM',
#   'gameName': 'teambuilder-match-6639461146',
#   'gameStartTimestamp': 1691448921696,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '13.15.524.1760',
#   'mapId': 12,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 13,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 109,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 300,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1220.9302770942027,
#      'damageTakenOnTeamPercentage': 0.2537514060811638,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 14,
#      'dodgeSkillShotsSmallWindow': 5,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 15,
#      'gameLength': 972.3306498,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 672.7307412190969,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.5714285714285714,
#      'killAfterHiddenWithAlly': 4,
#      'killParticipation': 0.7096774193548387,
#      'killedChampTookFullTeamDamageSurvived': 1,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 20,
#      'laneMinionsFirst10Minutes': 23,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 2,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6630,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 15,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 32,
#      'skillshotsHit': 44,
#      'snowballsHit': 10,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 22,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 22,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.1930282867097986,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 11430,
#     'champLevel': 13,
#     'championId': 2,
#     'championName': 'Olaf',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 206,
#     'damageDealtToObjectives': 206,
#     'damageDealtToTurrets': 206,
#     'damageSelfMitigated': 33925,
#     'dangerPings': 0,
#     'deaths': 14,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 1,
#     'goldEarned': 10901,
#     'goldSpent': 10650,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3748,
#     'item1': 3065,
#     'item2': 6630,
#     'item3': 0,
#     'item4': 3111,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 20,
#     'killingSprees': 2,
#     'kills': 9,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 119,
#     'magicDamageDealt': 131,
#     'magicDamageDealtToChampions': 131,
#     'magicDamageTaken': 15029,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 626, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 870, 'var2': 220, 'var3': 0},
#         {'perk': 9104, 'var1': 7, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 924, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0},
#         {'perk': 8139, 'var1': 894, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 31061,
#     'physicalDamageDealtToChampions': 13800,
#     'physicalDamageTaken': 20218,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 588,
#     'pushPings': 0,
#     'puuid': 'MbZ95JD7BR6Nr-bh8Vy1wosMwQMlpWi89FAT7y6h2czW25ilP-7xbL0mbk0M6wsITNgqCKr7STCsjQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 46,
#     'spell2Casts': 24,
#     'spell3Casts': 31,
#     'spell4Casts': 8,
#     'subteamPlacement': 0,
#     'summoner1Casts': 26,
#     'summoner1Id': 32,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'Ah1ZgHBvkbko4obmRZddBMhk3PdyR5kjSpAfHcVtsAtcwV4',
#     'summonerLevel': 228,
#     'summonerName': '햇뵹아리',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 11,
#     'timePlayed': 972,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 37627,
#     'totalDamageDealtToChampions': 19785,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 37444,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 6693,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 28,
#     'totalTimeCCDealt': 111,
#     'totalTimeSpentDead': 286,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 6434,
#     'trueDamageDealtToChampions': 5853,
#     'trueDamageTaken': 2197,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 19,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 250,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 1125,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1591.0188643834317,
#      'damageTakenOnTeamPercentage': 0.2161870561158262,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 4,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 38,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 15,
#      'gameLength': 972.3306498,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 678.49568310245,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 8,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.7777777777777777,
#      'killAfterHiddenWithAlly': 5,
#      'killParticipation': 0.8064516129032258,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 3,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 24,
#      'laneMinionsFirst10Minutes': 20,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6657,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 20,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 25,
#      'skillshotsHit': 73,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 25,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 24,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.2515390528653485,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 14575,
#     'champLevel': 15,
#     'championId': 45,
#     'championName': 'Veigar',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 556,
#     'damageDealtToObjectives': 556,
#     'damageDealtToTurrets': 556,
#     'damageSelfMitigated': 14678,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 10995,
#     'goldSpent': 10750,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6657,
#     'item1': 3158,
#     'item2': 3083,
#     'item3': 1028,
#     'item4': 3089,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 11,
#     'killingSprees': 2,
#     'kills': 6,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 156,
#     'magicDamageDealt': 46381,
#     'magicDamageDealtToChampions': 24397,
#     'magicDamageTaken': 13526,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 962, 'var2': 18, 'var3': 0},
#         {'perk': 8126, 'var1': 792, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8226, 'var1': 250, 'var2': 875, 'var3': 0},
#         {'perk': 8210, 'var1': 8, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 1913,
#     'physicalDamageDealtToChampions': 824,
#     'physicalDamageTaken': 16387,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5927,
#     'pushPings': 0,
#     'puuid': 'H319LfhyxTWa3PFBbE3HnSnIhiHlXY4jN0zbVMCkT6rRfWahodKdIhJFHYzY1cxFqj_TBxgxvhAnOQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 108,
#     'spell2Casts': 82,
#     'spell3Casts': 51,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 6,
#     'summonerId': 'iApzttPQGQ75hb-blDsH-iVJmDKBufajCrHZcyELYE4KepVwu4EgAQU2BA',
#     'summonerLevel': 129,
#     'summonerName': '아무렇지않지않음',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 65,
#     'timePlayed': 972,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 48856,
#     'totalDamageDealtToChampions': 25783,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 31901,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 4517,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 30,
#     'totalTimeCCDealt': 170,
#     'totalTimeSpentDead': 182,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 561,
#     'trueDamageDealtToChampions': 561,
#     'trueDamageTaken': 1988,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 14,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 170,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 975,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1279.3976805944353,
#      'damageTakenOnTeamPercentage': 0.18478981483095505,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 10,
#      'dodgeSkillShotsSmallWindow': 9,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 88.04411315917969,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 28,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 15,
#      'gameLength': 972.3306498,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 730.9498085758585,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 11,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.3,
#      'killAfterHiddenWithAlly': 9,
#      'killParticipation': 0.7419354838709677,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 3,
#      'landSkillShotsEarlyGame': 14,
#      'laneMinionsFirst10Minutes': 14,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6632,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 3,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 15,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 48,
#      'skillshotsHit': 33,
#      'snowballsHit': 7,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 23,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 23,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.2022719453672615,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 12313,
#     'champLevel': 14,
#     'championId': 234,
#     'championName': 'Viego',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 0,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 22742,
#     'dangerPings': 0,
#     'deaths': 10,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11845,
#     'goldSpent': 11600,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 1036,
#     'item1': 1036,
#     'item2': 3091,
#     'item3': 3153,
#     'item4': 6632,
#     'item5': 3047,
#     'item6': 0,
#     'itemsPurchased': 19,
#     'killingSprees': 2,
#     'kills': 9,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 213,
#     'magicDamageDealt': 5818,
#     'magicDamageDealtToChampions': 3020,
#     'magicDamageTaken': 11217,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 504, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 825, 'var2': 230, 'var3': 0},
#         {'perk': 9104, 'var1': 6, 'var2': 10, 'var3': 0},
#         {'perk': 8014, 'var1': 763, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0},
#         {'perk': 8139, 'var1': 856, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 28098,
#     'physicalDamageDealtToChampions': 17109,
#     'physicalDamageTaken': 14489,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 2073,
#     'pushPings': 0,
#     'puuid': 'JTwZ5Nv3wM4IVwZgXSDtySg4QndH-zhD5dheb9YUpvDGRLXzDoy4Z7bM61T8ULhCvcPaa3F6ovCgAw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 67,
#     'spell2Casts': 49,
#     'spell3Casts': 42,
#     'spell4Casts': 12,
#     'subteamPlacement': 0,
#     'summoner1Casts': 16,
#     'summoner1Id': 32,
#     'summoner2Casts': 1,
#     'summoner2Id': 4,
#     'summonerId': '4MckeWuQ9npFzIPIyPFTnumCJjzsdar6Hc8ExiRaVbpJwhle',
#     'summonerLevel': 214,
#     'summonerName': '실험체65',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 15,
#     'timePlayed': 972,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 34680,
#     'totalDamageDealtToChampions': 20733,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 27268,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 8040,
#     'totalHealsOnTeammates': 88,
#     'totalMinionsKilled': 26,
#     'totalTimeCCDealt': 79,
#     'totalTimeSpentDead': 234,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 763,
#     'trueDamageDealtToChampions': 603,
#     'trueDamageTaken': 1561,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 20,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 1,
#      'abilityUses': 135,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 862.2694309453312,
#      'damageTakenOnTeamPercentage': 0.21102058181063216,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 6,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 2291.01708984375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 111,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 15,
#      'gameLength': 972.3306498,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 590.6320535669903,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 16,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.7777777777777777,
#      'killAfterHiddenWithAlly': 9,
#      'killParticipation': 0.8064516129032258,
#      'killedChampTookFullTeamDamageSurvived': 1,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 2,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 10,
#      'landSkillShotsEarlyGame': 10,
#      'laneMinionsFirst10Minutes': 6,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6665,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 18,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 8,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 37,
#      'skillshotsHit': 33,
#      'snowballsHit': 8,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 4,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 25,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 25,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.1363242390333221,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 12862,
#     'champLevel': 14,
#     'championId': 412,
#     'championName': 'Thresh',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 270,
#     'damageDealtToObjectives': 270,
#     'damageDealtToTurrets': 270,
#     'damageSelfMitigated': 40681,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 9571,
#     'goldSpent': 8950,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 2031,
#     'item1': 1057,
#     'item2': 2051,
#     'item3': 6665,
#     'item4': 3121,
#     'item5': 3111,
#     'item6': 2052,
#     'itemsPurchased': 15,
#     'killingSprees': 1,
#     'kills': 5,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 174,
#     'magicDamageDealt': 18606,
#     'magicDamageDealtToChampions': 12284,
#     'magicDamageTaken': 11528,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5002, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8439, 'var1': 659, 'var2': 1637, 'var3': 0},
#         {'perk': 8463, 'var1': 3665, 'var2': 0, 'var3': 0},
#         {'perk': 8473, 'var1': 364, 'var2': 0, 'var3': 0},
#         {'perk': 8451, 'var1': 232, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9105, 'var1': 6, 'var2': 50, 'var3': 0},
#         {'perk': 8009, 'var1': 3442, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 3009,
#     'physicalDamageDealtToChampions': 1013,
#     'physicalDamageTaken': 14973,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 1635,
#     'pushPings': 0,
#     'puuid': 'a63bL3nfpkeA1fAqnpFDva147DIMBqNDEdw-fDU_WnfjmlGGkJbzBwWGshn59KzBG0nmAPmH9xk-ug',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 61,
#     'spell2Casts': 23,
#     'spell3Casts': 42,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 16,
#     'summoner2Id': 32,
#     'summonerId': 'bsuhQquEuRbNaeUiJaESamjVu_D4OY9FMp7esFKkhR2Nf3PUzA0qziJgkg',
#     'summonerLevel': 25,
#     'summonerName': '럭스여왕',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 63,
#     'timePlayed': 972,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 22290,
#     'totalDamageDealtToChampions': 13973,
#     'totalDamageShieldedOnTeammates': 1172,
#     'totalDamageTaken': 31139,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 3859,
#     'totalHealsOnTeammates': 1118,
#     'totalMinionsKilled': 10,
#     'totalTimeCCDealt': 142,
#     'totalTimeSpentDead': 196,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 675,
#     'trueDamageDealtToChampions': 675,
#     'trueDamageTaken': 4637,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 1,
#     'assists': 24,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 1,
#      'abilityUses': 147,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 300,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1371.520326212389,
#      'damageTakenOnTeamPercentage': 0.1342511411614228,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 5,
#      'dodgeSkillShotsSmallWindow': 4,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 3595.02734375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 43,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 15,
#      'gameLength': 972.3306498,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 670.851437416552,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 7,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 5.2,
#      'killAfterHiddenWithAlly': 5,
#      'killParticipation': 0.8387096774193549,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 19,
#      'laneMinionsFirst10Minutes': 43,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 20,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6692,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 19,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 2,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 22,
#      'skillshotsHit': 47,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 26,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 25,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.21683647602426928,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 2,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 15023,
#     'champLevel': 16,
#     'championId': 235,
#     'championName': 'Senna',
#     'championTransform': 0,
#     'commandPings': 5,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 389,
#     'damageDealtToObjectives': 389,
#     'damageDealtToTurrets': 389,
#     'damageSelfMitigated': 11457,
#     'dangerPings': 0,
#     'deaths': 5,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 10871,
#     'goldSpent': 9000,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6670,
#     'item1': 6692,
#     'item2': 3009,
#     'item3': 3004,
#     'item4': 1036,
#     'item5': 1036,
#     'item6': 2052,
#     'itemsPurchased': 18,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'NONE',
#     'largestCriticalStrike': 506,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 305,
#     'magicDamageDealt': 0,
#     'magicDamageDealtToChampions': 0,
#     'magicDamageTaken': 10597,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 4140, 'var2': 3264, 'var3': 0},
#         {'perk': 8009, 'var1': 3729, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 6, 'var2': 10, 'var3': 0},
#         {'perk': 8017, 'var1': 2529, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8410, 'var1': 135, 'var2': 0, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 63577,
#     'physicalDamageDealtToChampions': 22226,
#     'physicalDamageTaken': 8703,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5914,
#     'pushPings': 0,
#     'puuid': 'nAbtuqPG74lMCmjoMAQdtYLPqdHumpQ4y1Pg1xpODNUykl6Vz7RQA8FprQu8CJWu-bOOezPDKq985g',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 64,
#     'spell2Casts': 59,
#     'spell3Casts': 18,
#     'spell4Casts': 6,
#     'subteamPlacement': 0,
#     'summoner1Casts': 7,
#     'summoner1Id': 6,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'tUKg7AOQXLN04DjqNWILCjATOkA7S1lmMVEpFNoMgjmttpRFEd_XA9lYHg',
#     'summonerLevel': 178,
#     'summonerName': 'Strong7',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 60,
#     'timePlayed': 972,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 70772,
#     'totalDamageDealtToChampions': 22226,
#     'totalDamageShieldedOnTeammates': 476,
#     'totalDamageTaken': 19810,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 14830,
#     'totalHealsOnTeammates': 3118,
#     'totalMinionsKilled': 66,
#     'totalTimeCCDealt': 266,
#     'totalTimeSpentDead': 88,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 7195,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 509,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 22,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 93,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 2505.9892504172303,
#      'damageTakenOnTeamPercentage': 0.21067201848661404,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 4,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 15,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 607.6523301999999,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 22,
#      'gameLength': 972.3306498,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 776.7696650109241,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 3,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.888888888888889,
#      'killAfterHiddenWithAlly': 8,
#      'killParticipation': 0.7446808510638298,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 5,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 3,
#      'landSkillShotsEarlyGame': 12,
#      'laneMinionsFirst10Minutes': 31,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 21,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 3,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 24,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 20.774416400000064,
#      'skillshotsDodged': 27,
#      'skillshotsHit': 56,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 4,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 35,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 31,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 1,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.2868504263004511,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 1,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 14382,
#     'champLevel': 15,
#     'championId': 67,
#     'championName': 'Vayne',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 1665,
#     'damageDealtToObjectives': 1665,
#     'damageDealtToTurrets': 1665,
#     'damageSelfMitigated': 12860,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12587,
#     'goldSpent': 12500,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3184,
#     'item1': 3091,
#     'item2': 3006,
#     'item3': 3153,
#     'item4': 3124,
#     'item5': 1018,
#     'item6': 2052,
#     'itemsPurchased': 18,
#     'killingSprees': 3,
#     'kills': 13,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 3,
#     'longestTimeSpentLiving': 154,
#     'magicDamageDealt': 3953,
#     'magicDamageDealtToChampions': 2465,
#     'magicDamageTaken': 7605,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 128, 'var2': 19, 'var3': 0},
#         {'perk': 9111, 'var1': 929, 'var2': 350, 'var3': 0},
#         {'perk': 9104, 'var1': 7, 'var2': 20, 'var3': 0},
#         {'perk': 8017, 'var1': 2375, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8473, 'var1': 299, 'var2': 0, 'var3': 0},
#         {'perk': 8242, 'var1': 68, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 53680,
#     'physicalDamageDealtToChampions': 28965,
#     'physicalDamageTaken': 13006,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4031,
#     'pushPings': 0,
#     'puuid': '7JAOhJxgYmBD_ZYO8G7gh0b5RHPDC-w0zcPfU6bkCJtqacxxexbBWgmw1KT9g5ulbgMLT3sbxGg_Jw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 78,
#     'spell2Casts': 0,
#     'spell3Casts': 10,
#     'spell4Casts': 5,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 5,
#     'summoner2Id': 1,
#     'summonerId': 'ftOXyzZtLNqbhlQ5gjXyG0RuUf4AOsan9gtsQ-o9HUPMPu4',
#     'summonerLevel': 582,
#     'summonerName': 'MO 든',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 11,
#     'timePlayed': 972,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 67653,
#     'totalDamageDealtToChampions': 40610,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 24080,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 5771,
#     'totalHealsOnTeammates': 0,
# ...
#      'effectiveHealAndShielding': 624.6000366210938,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 607.6523301999999,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 22,
#      'gameLength': 972.3306498,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 834.6832084056866,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 6.333333333333333,
#      'killAfterHiddenWithAlly': 7,
#      'killParticipation': 0.8085106382978723,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 5,
#      'killsNearEnemyTurret': 6,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 5,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 62,
#      'laneMinionsFirst10Minutes': 31,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 34,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 3,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 3078,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 26,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 20.774416400000064,
#      'skillshotsDodged': 29,
#      'skillshotsHit': 158,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 4,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 38,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 35,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.3037518091416806,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 2,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 15474,
#     'champLevel': 16,
#     'championId': 81,
#     'championName': 'Ezreal',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 4003,
#     'damageDealtToObjectives': 4003,
#     'damageDealtToTurrets': 4003,
#     'damageSelfMitigated': 10052,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 4,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': True,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 13526,
#     'goldSpent': 10733,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 1036,
#     'item1': 0,
#     'item2': 6694,
#     'item3': 3042,
#     'item4': 3078,
#     'item5': 3158,
#     'item6': 2052,
#     'itemsPurchased': 18,
#     'killingSprees': 5,
#     'kills': 18,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 216,
#     'magicDamageDealt': 16039,
#     'magicDamageDealtToChampions': 10768,
#     'magicDamageTaken': 8844,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 1,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 238, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 6551, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 8, 'var2': 0, 'var3': 0},
#         {'perk': 8014, 'var1': 1311, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8226, 'var1': 250, 'var2': 410, 'var3': 0},
#         {'perk': 8210, 'var1': 28, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 73906,
#     'physicalDamageDealtToChampions': 32235,
#     'physicalDamageTaken': 9649,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4198,
#     'pushPings': 0,
#     'puuid': '4yhdUvNU66fCtD1IepEEbtTxDytsnAkohzOoHBkQEvMr9hHjW-RqGlPxo7wB5t9eh7JSUsuGhopBWg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 227,
#     'spell2Casts': 59,
#     'spell3Casts': 37,
#     'spell4Casts': 13,
#     'subteamPlacement': 0,
#     'summoner1Casts': 6,
#     'summoner1Id': 7,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'AgLCYOQbkmCpODsN0-otZgqjy5Q7rlcjvdkgBWl8nODZmw',
#     'summonerLevel': 647,
#     'summonerName': '까삐노예',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 3,
#     'timePlayed': 972,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 89945,
#     'totalDamageDealtToChampions': 43003,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 19312,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 4906,
#     'totalHealsOnTeammates': 624,
#     'totalMinionsKilled': 61,
#     'totalTimeCCDealt': 33,
#     'totalTimeSpentDead': 140,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 818,
#     'turretKills': 2,
#     'turretTakedowns': 3,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 34,
#     'baitPings': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 2,
#     'challenges': {'12AssistStreakCount': 1,
#      'abilityUses': 193,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 675,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 2035.864404544044,
#      'damageTakenOnTeamPercentage': 0.2923558603486116,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 7,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 43,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 607.6523301999999,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 22,
#      'gameLength': 972.3306498,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 803.0828710422393,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 11,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 6.428571428571429,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.9574468085106383,
#      'killedChampTookFullTeamDamageSurvived': 4,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 3,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 2,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 11,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 16,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 4,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 3,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6665,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 3,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 30,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 20.774416400000064,
#      'skillshotsDodged': 38,
#      'skillshotsHit': 0,
#      'snowballsHit': 13,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 13,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 45,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 41,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.2330371418138138,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 2,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -1,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 15433,
#     'champLevel': 16,
#     'championId': 82,
#     'championName': 'Mordekaiser',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 808,
#     'damageDealtToObjectives': 808,
#     'damageDealtToTurrets': 808,
#     'damageSelfMitigated': 78181,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 13014,
#     'goldSpent': 10650,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 2051,
#     'item1': 6665,
#     'item2': 3111,
#     'item3': 3075,
#     'item4': 3068,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 18,
#     'killingSprees': 5,
#     'kills': 11,
#     'lane': 'NONE',
#     'largestCriticalStrike': 54,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 181,
#     'magicDamageDealt': 54635,
#     'magicDamageDealtToChampions': 28467,
#     'magicDamageTaken': 9357,
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 1416, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 2824, 'var2': 450, 'var3': 0},
#         {'perk': 9105, 'var1': 4, 'var2': 20, 'var3': 0},
#         {'perk': 8299, 'var1': 1519, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8429, 'var1': 50, 'var2': 16, 'var3': 13},
#         {'perk': 8453, 'var1': 1219, 'var2': 1735, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 6520,
#     'physicalDamageDealtToChampions': 3464,
#     'physicalDamageTaken': 21399,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5764,
#     'pushPings': 0,
#     'puuid': 'rr8vp_is13emhYvFgjBVT4lryS0ykrArxIolVrwJi9LID6zoa9uYDb271aRfP7EFtb-CJWH2SdL7IA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 91,
#     'spell2Casts': 53,
#     'spell3Casts': 44,
#     'spell4Casts': 5,
#     'subteamPlacement': 0,
#     'summoner1Casts': 21,
#     'summoner1Id': 32,
#     'summoner2Casts': 3,
#     'summoner2Id': 4,
#     'summonerId': 'H0FUWdkxbBFDDsu-Qp6T2DcNCvTWXbNFu5E1lsmbhIW-lyQ',
#     'summonerLevel': 411,
#     'summonerName': '권지용 컴백해라',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 12,
#     'timePlayed': 972,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 64145,
#     'totalDamageDealtToChampions': 32992,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 33417,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 11418,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 30,
#     'totalTimeCCDealt': 24,
#     'totalTimeSpentDead': 152,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2990,
#     'trueDamageDealtToChampions': 1060,
#     'trueDamageTaken': 2660,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True}],
#   'platformId': 'KR',
#   'queueId': 450,
#   'teams': [{'bans': [],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 31},
#      'dragon': {'first': False, 'kills': 0},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 0}},
#     'teamId': 100,
#     'win': False},
#    {'bans': [],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': True, 'kills': 47},
#      'dragon': {'first': False, 'kills': 0},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 4}},
#     'teamId': 200,
#     'win': True}],
#   'tournamentCode': ''}}

# %%
for i in range(10):
    if r_match.json()['info']['participants'][i]['summonerName'] == 'Strong7':
        if r_match.json()['info']['participants'][i]['teamId'] == 100:
            print("블루팀")
            print("승리여부", r_match.json()['info']['participants'][i]['win'])
        else:
            print("레드팀")
            print(r_match.json()['info']['participants'][i]['win'])
            print("승리여부", r_match.json()['info']['participants'][i]['win'])
# Out:
# 블루팀
# 승리여부 False
