# %% [markdown]
# # Machine Learning

# %% [markdown]
# * 기계학습 및 인공지능에 대해서 설명하지 않음
#     * 관심이 있다면 요즘 많은 무료 강의들이 있고 책도 많기에 따로 공부하기 바람
#     * 본 강의에서는 분석한 데이터를 사용하여 결과를 만들어 내는 도구로써의 기계학습만을 다룸

# %%
#pip install scikit-learn

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# * 사용할 알고리즘
#     * Logistic Regression
#     * Decision Tree
#     * Random Forest

# %% [markdown]
# # Data analysis

# %% [markdown]
# * 롤 챌린저 게임 랭크 데이터 분석
# * 많은 데이터를 수업 도중에 수집하기는 어렵기에 이미 수집된 데이터 사용
# * ref
#     > https://www.kaggle.com/datasets/gyejr95/league-of-legends-challenger-ranked-games2020

# %% [markdown]
# ## Data information

# %% [markdown]
# * gameId: 고유 ID
# * gameDuraton : 경기 시간(초단위)
# * blueWins/ redWins: 승리 유무
# * blueFirstBlood/ redFirstBlood: 퍼블 유무
# * blueFirstTower/ redFirstTower: 포탑 선점 유무
# * blueFirstBaron/ redFirstBaron: 바론 선점 유무
# * blueFirstDragon/ redFirstDragon: 용 선점 유무
# * blueFirstInhibitor/ redFirstInhibitor: 억제기 선점 유무
# * blueDragonKills/ redDragonKills: 잡은 용의 수
# * blueBaronKills/ redBaronKills: 잡은 바론의 수
# * blueWardPlaced/ redWardPlaced : 설치한 와드의 개수
# * blueWardkills/ redWardkills : 제거한 와드의 개수
# * blueKills/ redKills : 팀의 킬 횟수
# * blueDeath/ redDeath : 팀의 죽은 횟수
# * blueAssist/ redAssist : 팀의 어시스트 횟수
# * blueChampionDamageDealt/ redChampionDamageDealt : 상대팀에게 가한 피해량
# * blueTotalGold/ redTotalGold : 총 골드량
# * blueTotalMinionKills/ redTotalMinionKills : 잡은 미니언의 수
# * blueTotalLevel/ redTotalLevel : 팀의 레벨 합
# * blueAvgLevel/ redAvgLevel : 팀의 레벨 평균
# * blueJungleMinionKills/ redJungleMinionKills : 잡은 정글 미니언의 수
# * blueKillingSpree/ redKillingSpree : 팀의 연속 킬 횟수
# * blueTotalHeal/redTotalHeal : 팀의 총 회복량
# * blueObjectDamageDealt/redObjectDamageDealt : 팀이 오브젝트에 가한 피해량

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Challenger_Ranked_Games.csv')

# %%
df
# Out:
#            gameId  gameDuraton  blueWins  blueFirstBlood  blueFirstTower  \
# 0      4247263043         1323         0               1               0
# 1      4247155821         1317         1               0               0
# 2      4243963257          932         0               0               0
# 3      4241678498         2098         0               0               0
# 4      4241538868         2344         1               1               1
# ...           ...          ...       ...             ...             ...
# 26899  4143231833         1468         0               1               0
# 26900  4157911901          970         0               1               1
# 26901  3764171638         1480         0               1               1
# 26902  4110201724         1837         1               1               0
# 26903  4100240254          948         1               1               1
#
#        blueFirstBaron  blueFirstDragon  blueFirstInhibitor  blueDragonKills  \
# 0                   0                0                   0                0
# 1                   0                1                   0                2
# 2                   0                0                   0                0
# 3                   1                1                   0                1
# 4                   1                1                   1                2
# ...               ...              ...                 ...              ...
# 26899               0                0                   0                1
# 26900               0                1                   0                3
# 26901               0                1                   0                1
# 26902               0                1                   0                3
# 26903               0                0                   0                1
#
#        blueBaronKills  ...  redAssist  redChampionDamageDealt  redTotalGold  \
# 0                   0  ...         68                   73016         49832
# 1                   0  ...          8                   44218         37136
# 2                   0  ...         20                   30797         35364
# 3                   1  ...         72                  125866         70528
# 4                   2  ...         83                  131536         74596
# ...               ...  ...        ...                     ...           ...
# 26899               0  ...         40                   75531         46558
# 26900               0  ...         31                   99837         70177
# 26901               0  ...         34                   55214         48849
# 26902               0  ...         29                   88366         52625
# 26903               0  ...          3                   16574         20972
#
#        redTotalMinionKills  redTotalLevel  redAvgLevel  redJungleMinionKills  \
# 0                      533             64         12.8                   138
# 1                      571             59         11.8                   134
# 2                      400             50         10.0                    89
# 3                      832             84         16.8                   205
# 4                      794             85         17.0                   227
# ...                    ...            ...          ...                   ...
# 26899                  478             64         12.8                   141
# 26900                  455             72         14.4                   136
# 26901                  636             66         13.2                   175
# 26902                  660             70         14.0                   168
# 26903                  351             40          8.0                    56
#
#        redKillingSpree  redTotalHeal  redObjectDamageDealt
# 0                    8         38711                 60463
# 1                    3         24829                 14105
# 2                    5         12589                 45201
# 3                    9         65312                 88202
# 4                    7         86431                 64141
# ...                ...           ...                   ...
# 26899                6         48596                 42733
# 26900               11         15817                 50217
# 26901                6         25448                 27675
# 26902                5         25003                 45455
# 26903                0          7138                  6808
#
# [26904 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26904 entries, 0 to 26903
# Data columns (total 50 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gameId                   26904 non-null  int64
#  1   gameDuraton              26904 non-null  int64
#  2   blueWins                 26904 non-null  int64
#  3   blueFirstBlood           26904 non-null  int64
#  4   blueFirstTower           26904 non-null  int64
#  5   blueFirstBaron           26904 non-null  int64
#  6   blueFirstDragon          26904 non-null  int64
#  7   blueFirstInhibitor       26904 non-null  int64
#  8   blueDragonKills          26904 non-null  int64
#  9   blueBaronKills           26904 non-null  int64
#  10  blueTowerKills           26904 non-null  int64
#  11  blueInhibitorKills       26904 non-null  int64
#  12  blueWardPlaced           26904 non-null  int64
#  13  blueWardkills            26904 non-null  int64
#  14  blueKills                26904 non-null  int64
#  15  blueDeath                26904 non-null  int64
#  16  blueAssist               26904 non-null  int64
#  17  blueChampionDamageDealt  26904 non-null  int64
#  18  blueTotalGold            26904 non-null  int64
#  19  blueTotalMinionKills     26904 non-null  int64
#  20  blueTotalLevel           26904 non-null  int64
#  21  blueAvgLevel             26904 non-null  float64
#  22  blueJungleMinionKills    26904 non-null  int64
#  23  blueKillingSpree         26904 non-null  int64
#  24  blueTotalHeal            26904 non-null  int64
#  25  blueObjectDamageDealt    26904 non-null  int64
#  26  redWins                  26904 non-null  int64
#  27  redFirstBlood            26904 non-null  int64
#  28  redFirstTower            26904 non-null  int64
#  29  redFirstBaron            26904 non-null  int64
#  30  redFirstDragon           26904 non-null  int64
#  31  redFirstInhibitor        26904 non-null  int64
#  32  redDragonKills           26904 non-null  int64
#  33  redBaronKills            26904 non-null  int64
#  34  redTowerKills            26904 non-null  int64
#  35  redInhibitorKills        26904 non-null  int64
#  36  redWardPlaced            26904 non-null  int64
#  37  redWardkills             26904 non-null  int64
#  38  redKills                 26904 non-null  int64
#  39  redDeath                 26904 non-null  int64
#  40  redAssist                26904 non-null  int64
#  41  redChampionDamageDealt   26904 non-null  int64
#  42  redTotalGold             26904 non-null  int64
#  43  redTotalMinionKills      26904 non-null  int64
#  44  redTotalLevel            26904 non-null  int64
#  45  redAvgLevel              26904 non-null  float64
#  46  redJungleMinionKills     26904 non-null  int64
#  47  redKillingSpree          26904 non-null  int64
#  48  redTotalHeal             26904 non-null  int64
#  49  redObjectDamageDealt     26904 non-null  int64
# dtypes: float64(2), int64(48)
# memory usage: 10.3 MB

# %%
blue_df = df.iloc[:, 1:26]
red_df = pd.concat([df.iloc[:, 1], df.iloc[:,26:]], axis=1)

# %%
blue_df
# Out:
#        gameDuraton  blueWins  blueFirstBlood  blueFirstTower  blueFirstBaron  \
# 0             1323         0               1               0               0
# 1             1317         1               0               0               0
# 2              932         0               0               0               0
# 3             2098         0               0               0               1
# 4             2344         1               1               1               1
# ...            ...       ...             ...             ...             ...
# 26899         1468         0               1               0               0
# 26900          970         0               1               1               0
# 26901         1480         0               1               1               0
# 26902         1837         1               1               0               0
# 26903          948         1               1               1               0
#
#        blueFirstDragon  blueFirstInhibitor  blueDragonKills  blueBaronKills  \
# 0                    0                   0                0               0
# 1                    1                   0                2               0
# 2                    0                   0                0               0
# 3                    1                   0                1               1
# 4                    1                   1                2               2
# ...                ...                 ...              ...             ...
# 26899                0                   0                1               0
# 26900                1                   0                3               0
# 26901                1                   0                1               0
# 26902                1                   0                3               0
# 26903                0                   0                1               0
#
#        blueTowerKills  ...  blueAssist  blueChampionDamageDealt  \
# 0                   0  ...          22                    56039
# 1                   4  ...          31                    60243
# 2                   0  ...           8                    24014
# 3                   2  ...          45                   101607
# 4                  11  ...          47                   134826
# ...               ...  ...         ...                      ...
# 26899               0  ...          50                    99418
# 26900               5  ...          36                    61816
# 26901               4  ...          19                    51604
# 26902               5  ...          66                    93059
# 26903               4  ...          19                    22427
#
#        blueTotalGold  blueTotalMinionKills  blueTotalLevel  blueAvgLevel  \
# 0              37001                   440              56          11.2
# 1              41072                   531              63          12.6
# 2              22929                   306              42           8.4
# 3              63447                   774              80          16.0
# 4              74955                   831              83          16.6
# ...              ...                   ...             ...           ...
# 26899          41437                   438              60          12.0
# 26900          61221                   346              65          13.0
# 26901          45013                   568              63          12.6
# 26902          58160                   640              76          15.2
# 26903          30001                   399              50          10.0
#
#        blueJungleMinionKills  blueKillingSpree  blueTotalHeal  \
# 0                        105                 4          31035
# 1                        111                 3          26397
# 2                         64                 0           6567
# 3                        226                 3          24718
# 4                        252                 5          37161
# ...                      ...               ...            ...
# 26899                    106                 8          20122
# 26900                     28                 5          32837
# 26901                    132                 4          18131
# 26902                    168                 7          75427
# 26903                     89                 3          10791
#
#        blueObjectDamageDealt
# 0                       5675
# 1                      45303
# 2                       5651
# 3                      31019
# 4                      95287
# ...                      ...
# 26899                  13309
# 26900                  44640
# 26901                  45242
# 26902                  60486
# 26903                  24827
#
# [26904 rows x 25 columns]

# %%
red_df
# Out:
#        gameDuraton  redWins  redFirstBlood  redFirstTower  redFirstBaron  \
# 0             1323        1              0              1              0
# 1             1317        0              1              1              0
# 2              932        1              1              1              0
# 3             2098        1              1              1              0
# 4             2344        0              0              0              0
# ...            ...      ...            ...            ...            ...
# 26899         1468        1              0              1              0
# 26900          970        1              0              0              0
# 26901         1480        1              0              0              0
# 26902         1837        0              0              1              1
# 26903          948        0              0              0              0
#
#        redFirstDragon  redFirstInhibitor  redDragonKills  redBaronKills  \
# 0                   1                  1               3              0
# 1                   0                  0               0              0
# 2                   1                  1               2              0
# 3                   0                  0               3              1
# 4                   0                  0               3              1
# ...               ...                ...             ...            ...
# 26899               1                  0               2              0
# 26900               0                  1               0              0
# 26901               0                  0               1              0
# 26902               0                  0               2              1
# 26903               1                  0               1              0
#
#        redTowerKills  ...  redAssist  redChampionDamageDealt  redTotalGold  \
# 0                  9  ...         68                   73016         49832
# 1                  2  ...          8                   44218         37136
# 2                  5  ...         20                   30797         35364
# 3                  6  ...         72                  125866         70528
# 4                  6  ...         83                  131536         74596
# ...              ...  ...        ...                     ...           ...
# 26899              4  ...         40                   75531         46558
# 26900             10  ...         31                   99837         70177
# 26901              3  ...         34                   55214         48849
# 26902              4  ...         29                   88366         52625
# 26903              0  ...          3                   16574         20972
#
#        redTotalMinionKills  redTotalLevel  redAvgLevel  redJungleMinionKills  \
# 0                      533             64         12.8                   138
# 1                      571             59         11.8                   134
# 2                      400             50         10.0                    89
# 3                      832             84         16.8                   205
# 4                      794             85         17.0                   227
# ...                    ...            ...          ...                   ...
# 26899                  478             64         12.8                   141
# 26900                  455             72         14.4                   136
# 26901                  636             66         13.2                   175
# 26902                  660             70         14.0                   168
# 26903                  351             40          8.0                    56
#
#        redKillingSpree  redTotalHeal  redObjectDamageDealt
# 0                    8         38711                 60463
# 1                    3         24829                 14105
# 2                    5         12589                 45201
# 3                    9         65312                 88202
# 4                    7         86431                 64141
# ...                ...           ...                   ...
# 26899                6         48596                 42733
# 26900               11         15817                 50217
# 26901                6         25448                 27675
# 26902                5         25003                 45455
# 26903                0          7138                  6808
#
# [26904 rows x 25 columns]

# %%
for i in blue_df.iloc[:, 2:7].columns:
    display(pd.crosstab(blue_df[i], blue_df['blueWins'], margins=True).style.background_gradient(cmap='Reds'))
# Out:
# <style type="text/css">
# #T_b5783_row0_col0 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_b5783_row0_col1, #T_b5783_row0_col2, #T_b5783_row1_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_b5783_row1_col1 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_b5783_row1_col2 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_b5783_row2_col0, #T_b5783_row2_col1, #T_b5783_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b5783">
#   <thead>
#     <tr>
#       <th class="index_name level0" >blueWins</th>
#       <th id="T_b5783_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b5783_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_b5783_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >blueFirstBlood</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5783_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5783_row0_col0" class="data row0 col0" >8066</td>
#       <td id="T_b5783_row0_col1" class="data row0 col1" >5291</td>
#       <td id="T_b5783_row0_col2" class="data row0 col2" >13357</td>
#     </tr>
#     <tr>
#       <th id="T_b5783_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b5783_row1_col0" class="data row1 col0" >5384</td>
#       <td id="T_b5783_row1_col1" class="data row1 col1" >8163</td>
#       <td id="T_b5783_row1_col2" class="data row1 col2" >13547</td>
#     </tr>
#     <tr>
#       <th id="T_b5783_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_b5783_row2_col0" class="data row2 col0" >13450</td>
#       <td id="T_b5783_row2_col1" class="data row2 col1" >13454</td>
#       <td id="T_b5783_row2_col2" class="data row2 col2" >26904</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_15416_row0_col0 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_15416_row0_col1, #T_15416_row0_col2, #T_15416_row1_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_15416_row1_col1 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_15416_row1_col2 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_15416_row2_col0, #T_15416_row2_col1, #T_15416_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_15416">
#   <thead>
#     <tr>
#       <th class="index_name level0" >blueWins</th>
#       <th id="T_15416_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_15416_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_15416_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >blueFirstTower</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15416_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15416_row0_col0" class="data row0 col0" >9397</td>
#       <td id="T_15416_row0_col1" class="data row0 col1" >3366</td>
#       <td id="T_15416_row0_col2" class="data row0 col2" >12763</td>
#     </tr>
#     <tr>
#       <th id="T_15416_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_15416_row1_col0" class="data row1 col0" >4053</td>
#       <td id="T_15416_row1_col1" class="data row1 col1" >10088</td>
#       <td id="T_15416_row1_col2" class="data row1 col2" >14141</td>
#     </tr>
#     <tr>
#       <th id="T_15416_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_15416_row2_col0" class="data row2 col0" >13450</td>
#       <td id="T_15416_row2_col1" class="data row2 col1" >13454</td>
#       <td id="T_15416_row2_col2" class="data row2 col2" >26904</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_51f57_row0_col0 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_51f57_row0_col1 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_51f57_row0_col2 {
#   background-color: #e02c26;
#   color: #f1f1f1;
# }
# #T_51f57_row1_col0, #T_51f57_row1_col1, #T_51f57_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_51f57_row2_col0, #T_51f57_row2_col1, #T_51f57_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_51f57">
#   <thead>
#     <tr>
#       <th class="index_name level0" >blueWins</th>
#       <th id="T_51f57_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_51f57_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_51f57_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >blueFirstBaron</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51f57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51f57_row0_col0" class="data row0 col0" >12286</td>
#       <td id="T_51f57_row0_col1" class="data row0 col1" >8051</td>
#       <td id="T_51f57_row0_col2" class="data row0 col2" >20337</td>
#     </tr>
#     <tr>
#       <th id="T_51f57_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51f57_row1_col0" class="data row1 col0" >1164</td>
#       <td id="T_51f57_row1_col1" class="data row1 col1" >5403</td>
#       <td id="T_51f57_row1_col2" class="data row1 col2" >6567</td>
#     </tr>
#     <tr>
#       <th id="T_51f57_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_51f57_row2_col0" class="data row2 col0" >13450</td>
#       <td id="T_51f57_row2_col1" class="data row2 col1" >13454</td>
#       <td id="T_51f57_row2_col2" class="data row2 col2" >26904</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6c9aa_row0_col0 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_6c9aa_row0_col1, #T_6c9aa_row1_col0, #T_6c9aa_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_6c9aa_row0_col2 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_6c9aa_row1_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_6c9aa_row2_col0, #T_6c9aa_row2_col1, #T_6c9aa_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6c9aa">
#   <thead>
#     <tr>
#       <th class="index_name level0" >blueWins</th>
#       <th id="T_6c9aa_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6c9aa_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6c9aa_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >blueFirstDragon</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c9aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c9aa_row0_col0" class="data row0 col0" >9754</td>
#       <td id="T_6c9aa_row0_col1" class="data row0 col1" >6218</td>
#       <td id="T_6c9aa_row0_col2" class="data row0 col2" >15972</td>
#     </tr>
#     <tr>
#       <th id="T_6c9aa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c9aa_row1_col0" class="data row1 col0" >3696</td>
#       <td id="T_6c9aa_row1_col1" class="data row1 col1" >7236</td>
#       <td id="T_6c9aa_row1_col2" class="data row1 col2" >10932</td>
#     </tr>
#     <tr>
#       <th id="T_6c9aa_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_6c9aa_row2_col0" class="data row2 col0" >13450</td>
#       <td id="T_6c9aa_row2_col1" class="data row2 col1" >13454</td>
#       <td id="T_6c9aa_row2_col2" class="data row2 col2" >26904</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a8eed_row0_col0 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_a8eed_row0_col1, #T_a8eed_row1_col0, #T_a8eed_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_a8eed_row0_col2 {
#   background-color: #fc8464;
#   color: #f1f1f1;
# }
# #T_a8eed_row1_col1 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_a8eed_row2_col0, #T_a8eed_row2_col1, #T_a8eed_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a8eed">
#   <thead>
#     <tr>
#       <th class="index_name level0" >blueWins</th>
#       <th id="T_a8eed_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a8eed_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a8eed_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >blueFirstInhibitor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8eed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8eed_row0_col0" class="data row0 col0" >12646</td>
#       <td id="T_a8eed_row0_col1" class="data row0 col1" >4381</td>
#       <td id="T_a8eed_row0_col2" class="data row0 col2" >17027</td>
#     </tr>
#     <tr>
#       <th id="T_a8eed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8eed_row1_col0" class="data row1 col0" >804</td>
#       <td id="T_a8eed_row1_col1" class="data row1 col1" >9073</td>
#       <td id="T_a8eed_row1_col2" class="data row1 col2" >9877</td>
#     </tr>
#     <tr>
#       <th id="T_a8eed_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_a8eed_row2_col0" class="data row2 col0" >13450</td>
#       <td id="T_a8eed_row2_col1" class="data row2 col1" >13454</td>
#       <td id="T_a8eed_row2_col2" class="data row2 col2" >26904</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.boxplot(data=blue_df.iloc[:, 8:26], orient='h')
plt.show()

# %%
for feature in ['blueChampionDamageDealt', 'blueTotalGold', 'blueTotalHeal', 'blueObjectDamageDealt']:
    q1 = blue_df[feature].quantile(0.25)
    q3 = blue_df[feature].quantile(0.75)
    iqr = q3 - q1

    condition=blue_df[feature] > (q3 + 1.5 * iqr)
    target=blue_df[condition].index
    blue_df.drop(target,inplace=True)

# %%
sns.boxplot(data=blue_df.iloc[:, 8:26], orient='h')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data=blue_df.corr(), annot=True, annot_kws={"size": 7}, fmt=".2f")
plt.show()

# %% [markdown]
# # Learning

# %% [markdown]
# ## Feature selection

# %% [markdown]
# * blueDeath를 포함하면 정확도 매우 향상
#     * 처음엔 없이 해볼 것

# %%
corr1 = blue_df.corr().loc['blueWins'][blue_df.corr().loc['blueWins'] >= 0.375].index
corr2 = blue_df.corr().loc['blueWins'][blue_df.corr().loc['blueWins'] <= -0.375].index
corr = np.append(corr1, corr2)
corr
# Out:
# array(['blueWins', 'blueFirstTower', 'blueFirstBaron',
#        'blueFirstInhibitor', 'blueDragonKills', 'blueTowerKills',
#        'blueInhibitorKills', 'blueKills', 'blueAssist',
#        'blueKillingSpree', 'blueObjectDamageDealt', 'blueDeath'],
#       dtype=object)

# %% [markdown]
# corr = blue_df.corr().loc['blueWins'][blue_df.corr().loc['blueWins'] >= 0.375].index
# corr

# %%
blue_df[corr[1:]]
# Out:
#        blueFirstTower  blueFirstBaron  blueFirstInhibitor  blueDragonKills  \
# 0                   0               0                   0                0
# 1                   0               0                   0                2
# 2                   0               0                   0                0
# 3                   0               1                   0                1
# 4                   1               1                   1                2
# ...               ...             ...                 ...              ...
# 26898               1               1                   1                3
# 26899               0               0                   0                1
# 26900               1               0                   0                3
# 26901               1               0                   0                1
# 26903               1               0                   0                1
#
#        blueTowerKills  blueInhibitorKills  blueKills  blueAssist  \
# 0                   0                   0         15          22
# 1                   4                   0         19          31
# 2                   0                   0          5           8
# 3                   2                   0         26          45
# 4                  11                   3         27          47
# ...               ...                 ...        ...         ...
# 26898               7                   1         30          31
# 26899               0                   0         24          50
# 26900               5                   1         29          36
# 26901               4                   0         14          19
# 26903               4                   0         10          19
#
#        blueKillingSpree  blueObjectDamageDealt  blueDeath
# 0                     4                   5675         31
# 1                     3                  45303          8
# 2                     0                   5651         20
# 3                     3                  31019         36
# 4                     5                  95287         40
# ...                 ...                    ...        ...
# 26898                 9                  57020         18
# 26899                 8                  13309         28
# 26900                 5                  44640         42
# 26901                 4                  45242         20
# 26903                 3                  24827          2
#
# [25682 rows x 11 columns]

# %% [markdown]
# ## Split data

# %%
x = blue_df[corr[1:]]
y = blue_df['blueWins']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y)

# %% [markdown]
# ## Train and Test

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression(max_iter=200)
lr.fit(x_train, y_train)

lr_predict = lr.predict(x_test)
lr_accuracy = accuracy_score(y_test, lr_predict)
lr_accuracy
# Out:
# 0.9567841152423594

# %% [markdown]
# ### Decision Tree

# %%
dt = DecisionTreeClassifier(max_depth=7)
dt.fit(x_train, y_train)

dt_predict = dt.predict(x_test)
dt_accuracy = accuracy_score(y_test, dt_predict)
dt_accuracy
# Out:
# 0.9598987736032704

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestClassifier(n_estimators=200)
rf.fit(x_train, y_train)

rf_predict = rf.predict(x_test)
rf_accuracy = accuracy_score(y_test, rf_predict)
rf_accuracy
# Out:
# 0.9678800856531049

# %% [markdown]
# # Result Visualization

# %%
def cmatrix(target, prediction, title):
    c_matrix = np.zeros([2, 2]).astype(np.int64)

    for i in range(target.shape[0]):
        idx_target = np.abs(target[i].astype(int) - 1)
        idx_output = np.abs(prediction[i].astype(int) - 1)

        c_matrix[idx_target, idx_output] += 1

    c_matrix_frame = pd.DataFrame(c_matrix, index=['Actual(P)', 'Actual(N)'], columns=['Predicted(P)', 'Predicted(N)'])

    plt.figure(figsize=(4, 3))
    plt.title(title)
    sns.heatmap(c_matrix_frame, annot = True, fmt = 'd',cmap = 'Reds')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.xticks([0.5, 1.5],['P', 'N'])
    plt.yticks([0.5, 1.5],['P', 'N'])
    plt.show()
    
    TP = c_matrix[0][0]
    FP = c_matrix[1][0]
    FN = c_matrix[0][1]
    TN = c_matrix[1][1]
    
    Accuracy = (TP + TN) / (TP + TN + FP + FN)
    Precision = TP / (TP + FP)
    Recall = TP / (TP + FN)
    Specificity = TN / (TN + FP)
    F1_score = 2 * (Precision * Recall) / (Precision + Recall)
    print('Accuracy:', Accuracy)
    print('Precision:', Precision)
    print('Recall:', Recall)
    print('Specificity:', Specificity)
    print('F1_score:', F1_score)

# %% [markdown]
# ## Logistic Regression

# %%
cmatrix(np.array(y_test), lr_predict, 'Logistic Regression')
# Out:
# Accuracy: 0.9567841152423594
# Precision: 0.953579858379229
# Recall: 0.9588607594936709
# Specificity: 0.9547719432732847
# F1_score: 0.9562130177514793

# %% [markdown]
# ## Decision Tree

# %%
sns.barplot(x=dt.feature_importances_, y=x_train.columns)
plt.show()

# %%
cmatrix(np.array(y_test), dt_predict, 'Decision Tree')
# Out:
# Accuracy: 0.9598987736032704
# Precision: 0.9407744874715261
# Recall: 0.9802215189873418
# Specificity: 0.9402069758528172
# F1_score: 0.9600929872142581

# %%
from sklearn import tree
plt.figure(figsize=(10, 8))
tree.plot_tree(dt, feature_names = x_test.columns, class_names = np.unique(y_test.astype('str')), filled=True)
plt.show()

# %% [markdown]
# ## Random Forest

# %%
sns.barplot(x=rf.feature_importances_, y=x_train.columns)
plt.show()

# %%
cmatrix(np.array(y_test), rf_predict, 'Random Forest')
# Out:
# Accuracy: 0.9678800856531049
# Precision: 0.9581233036060488
# Recall: 0.9774525316455697
# Specificity: 0.9586048294365658
# F1_score: 0.9676914039553554

# %% [markdown]
# # Application

# %% [markdown]
# * 그랜드 마스터 데이터에 모델 적용하기

# %%
adf = pd.read_csv('GrandMaster_Ranked_Games.csv')

# %%
ablue_df = adf.iloc[:, 1:26]

# %%
ablue_df
# Out:
#        gameDuraton  blueWins  blueFirstBlood  blueFirstTower  blueFirstBaron  \
# 0             2098         0               0               0               1
# 1             1686         0               0               1               0
# 2             1588         1               1               1               1
# 3             1126         1               0               1               0
# 4             1262         1               0               0               0
# ...            ...       ...             ...             ...             ...
# 65891         1928         0               1               0               0
# 65892         1837         1               1               0               0
# 65893          948         1               1               1               0
# 65894         2479         1               1               0               0
# 65895         1129         1               0               1               0
#
#        blueFirstDragon  blueFirstInhibitor  blueDragonKills  blueBaronKills  \
# 0                    1                   0                1               1
# 1                    0                   0                0               0
# 2                    0                   1                2               1
# 3                    1                   0                1               0
# 4                    1                   1                3               0
# ...                ...                 ...              ...             ...
# 65891                0                   0                2               0
# 65892                1                   0                3               0
# 65893                0                   0                1               0
# 65894                0                   0                3               1
# 65895                0                   1                1               0
#
#        blueTowerKills  ...  blueAssist  blueChampionDamageDealt  \
# 0                   2  ...          45                   101607
# 1                   2  ...          30                    70270
# 2                  10  ...          88                   102449
# 3                   4  ...          34                    56652
# 4                   7  ...          38                    57342
# ...               ...  ...         ...                      ...
# 65891               3  ...          40                    97060
# 65892               5  ...          66                    93059
# 65893               4  ...          19                    22427
# 65894               7  ...          83                   142725
# 65895               6  ...          26                    48427
#
#        blueTotalGold  blueTotalMinionKills  blueTotalLevel  blueAvgLevel  \
# 0              63447                   774              80          16.0
# 1              47107                   601              65          13.0
# 2              59163                   613              71          14.2
# 3              39014                   486              57          11.4
# 4              42933                   509              61          12.2
# ...              ...                   ...             ...           ...
# 65891          61378                   771              76          15.2
# 65892          58160                   640              76          15.2
# 65893          30001                   399              50          10.0
# 65894          82466                   803              89          17.8
# 65895          37603                   426              57          11.4
#
#        blueJungleMinionKills  blueKillingSpree  blueTotalHeal  \
# 0                        226                 3          24718
# 1                        136                 5          20503
# 2                        157                 7          28612
# 3                        115                 5          17630
# 4                        129                 4          13040
# ...                      ...               ...            ...
# 65891                    177                 4          23467
# 65892                    168                 7          75427
# 65893                     89                 3          10791
# 65894                    251                13          67496
# 65895                    118                 3          22224
#
#        blueObjectDamageDealt
# 0                      31019
# 1                      31788
# 2                      67404
# 3                      37483
# 4                      48691
# ...                      ...
# 65891                  31943
# 65892                  60486
# 65893                  24827
# 65894                  98972
# 65895                  43316
#
# [65896 rows x 25 columns]

# %%
x = ablue_df[corr[1:]]
y = ablue_df['blueWins']

# %% [markdown]
# ### Logistic Regression

# %%
alr_predict = lr.predict(x)
alr_accuracy = accuracy_score(y, alr_predict)
alr_accuracy
# Out:
# 0.9457781959451257

# %% [markdown]
# ### Decision Tree

# %%
adt_predict = dt.predict(x)
adt_accuracy = accuracy_score(y, adt_predict)
adt_accuracy
# Out:
# 0.9570838897656914

# %% [markdown]
# ### Random Forest

# %%
arf_predict = rf.predict(x)
arf_accuracy = accuracy_score(y, arf_predict)
arf_accuracy
# Out:
# 0.9694518635425519
